# %% [markdown]
# <a href="https://colab.research.google.com/github/dubeyjideepak/MLProjects/blob/main/paisa_bazar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Paisa Bazar Credit Score Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/dubeyjideepak/MLProjects

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Explore the dataset to alanyse the Credit score of each individual, by findind trends, patterns, given the columns and rows available in the dataset.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Bussiness objective is to reduce the credit defaults by analysing the dataset and users behaviour, to help banks to find decent credit card customer.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# !pip install gdown
# The file will be saved in the current directory of the notebook

# %%
# !gdown --id "1P7f1fa0v3hmp5Lc3pbzfVRKOoxY9B66B"

# %%
df = pd.read_csv('dataset.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"The number of rows: {df.shape[0]}, and number of columns: {df.shape[1]}")

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"The number of duplicate values: {df.duplicated().sum()}")

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(f"The number of missing values: {df.isnull().sum().sum()}")

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset has 28 columns and 100000 unique rows, most columns are numbers type, no missing or duplicate values, the dataset core focus is about inviduals loan taking and paying back pattern, which is final is generating a credit score to assist paisabazar whether an invidual will be paying loans if he/she is granted any loan

# %% [markdown]
# ### ***2. Understanding Your Variables***

# %%
# Dataset Columns
display(df.columns)

# %% [markdown]
# ID: Unique identifier for each record in the dataset (integer).
#
# Customer_ID: Unique identifier representing each customer across records (integer).
#
# Month: Numeric representation of the month for which the financial record is stored (integer / categorical).
#
# Name: Name of the customer associated with the financial record (text/string).
#
# Age: Age of the customer in years (floating-point numeric).
#
# SSN: Social Security or identification number of the customer used for identity tracking (floating-point numeric though logically an identifier).
#
# Occupation: Profession or employment category of the customer (categorical text).
#
# Annual_Income: Total yearly income earned by the customer (floating-point numeric).
#
# Monthly_Inhand_Salary: Net monthly salary received by the customer after deductions (floating-point numeric).
#
# Num_Bank_Accounts: Total number of bank accounts owned by the customer (floating-point numeric representing count).
#
# Num_Credit_Card: Number of credit cards held by the customer (floating-point numeric representing count).
#
# Interest_Rate: Interest rate applied to loans or credit facilities of the customer (floating-point numeric).
#
# Num_of_Loan: Total number of loans taken by the customer (floating-point numeric representing count).
#
# Type_of_Loan: Category or type of loan taken by the customer such as personal, home, or auto loan (categorical text).
#
# Delay_from_due_date: Number of days the payment was delayed after the due date (floating-point numeric).
#
# Num_of_Delayed_Payment: Total count of delayed payments made by the customer (floating-point numeric).
#
# Changed_Credit_Limit: Amount or indicator representing changes in the customer's credit limit (floating-point numeric).
#
# Num_Credit_Inquiries: Number of times the customer's credit report has been checked by lenders (floating-point numeric).
#
# Credit_Mix: Type or diversity of credit accounts used by the customer (categorical text).
#
# Outstanding_Debt: Total unpaid debt amount currently owed by the customer (floating-point numeric).
#
# Credit_Utilization_Ratio: Percentage of available credit currently being used by the customer (floating-point numeric).
#
# Credit_History_Age: Length of time the customer has maintained credit accounts (floating-point numeric representing duration).
#
# Payment_of_Min_Amount: Indicator describing whether the customer usually pays only the minimum required credit payment (categorical text).
#
# Total_EMI_per_month: Total amount of EMI payments the customer makes every month (floating-point numeric).
#
# Amount_invested_monthly: Amount of money the customer invests each month (floating-point numeric).
#
# Payment_Behaviour: Pattern describing how the customer manages and pays credit obligations (categorical text).
#
# Monthly_Balance: Remaining account balance after monthly income and expenses (floating-point numeric).
#
# Credit_Score: Creditworthiness category assigned to the customer based on financial behavior (categorical text).

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Age**
#
# Customer age ranges from 14 to 56 years. The average age is about 33 years and the median is also around 33, which means the distribution is fairly **balanced**. The standard deviation shows moderate spread, so most customers are around their early thirties.
#
# **Annual_Income**
#
# Annual income ranges from about 7006 to 179987. The average income is about 50505 while the median is around 36999. Since the mean is higher than the median, the data is slightly right skewed, meaning some customers have very high incomes that increase the average.
#
# **Monthly_Inhand_Salary**
#
# Monthly in-hand salary ranges from about 303 to 15204 with an average around 4197 and a median around 3095. The spread is quite large and the mean being higher than the median suggests a slight right skew due to higher salaries of some customers.
#
# **Num_Bank_Accounts**
#
# The number of bank accounts ranges from 0 to 11. The average is about 5.37 and the median is 5, which indicates most customers have around five bank accounts. The spread is moderate.
#
# **Num_Credit_Card**
#
# The number of credit cards ranges from 0 to 11. The mean is about 5.53 and the median is 5, showing a fairly balanced distribution. Most customers have between 4 and 7 credit cards.
#
# **Interest_Rate**
#
# Interest rates range from 1 to 34 percent with an average of about 14.5 percent and a median of 13 percent. Since the mean is slightly higher than the median, the distribution shows a small right skew.
#
# **Delay_from_due_date**
#
# Payment delay ranges from 0 to 62 days. The average delay is about 21 days while the median is 18 days. This indicates some customers delay payments more than others, causing a slight right skew.
#
# **Num_of_Delayed_Payment**
#
# The number of delayed payments ranges from 0 to 25. The average is about 13.3 and the median is 14, which suggests the distribution is fairly balanced with moderate spread.
#
# **Changed_Credit_Limit**
#
# Credit limit changes range from about 0.5 to 29.98. The average is around 10.47 while the median is 9.4. The data shows moderate spread with a slight right skew.
#
# **Num_Credit_Inquiries**
#
# Credit inquiries range from 0 to 17. The mean is about 5.8 and the median is 5, suggesting a small right skew and moderate variation among customers.
#
# **Outstanding_Debt**
#
# Outstanding debt ranges from about 0.23 to 4998. The average debt is around 1426 while the median is about 1166. Since the mean is higher than the median, the distribution is right skewed, meaning some customers have very high debts.
#
# **Credit_Utilization_Ratio**
#
# Credit utilization ranges from 20 percent to 50 percent. The mean and median are both around 32 percent, which indicates a fairly balanced distribution with moderate spread.
#
# **Credit_History_Age**
#
# Credit history age ranges from 1 to 404. The average is about 221 and the median is about 219, suggesting the distribution is fairly symmetric but with a wide spread.
#
# **Total_EMI_per_month**
#
# Monthly EMI ranges from 0 to about 1779. The average EMI is around 108 while the median is about 66. The higher mean indicates a right skew caused by some customers paying very high EMIs.
#
# **Amount_invested_monthly**
#
# Monthly investment ranges from 0 to about 434. The average is around 55 while the median is about 45. This indicates a slight right skew with some customers investing much higher amounts.
#
# **Monthly_Balance**
#
# Monthly balance ranges from about 0 to 1183. The average balance is around 392 while the median is about 333. The higher mean suggests a slight right skew due to some customers maintaining higher balances.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique().sort_values()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

#Remove ID,Customer_ID, Name and SSN columns
df.drop(['ID','Customer_ID','SSN', 'Name'],axis=1,inplace=True)

# %%
#Mapping large payment behaviour item name to short to get them shown on the chart properly later
mapping = {
    "Low_spent_Small_value_payments": "Low_Small",
    "High_spent_Medium_value_payments": "High_Medium",
    "High_spent_Large_value_payments": "High_Large",
    "Low_spent_Medium_value_payments": "Low_Medium",
    "High_spent_Small_value_payments": "High_Small",
    "Low_spent_Large_value_payments": "Low_Large"
}

df["Payment_Behaviour"] = df["Payment_Behaviour"].replace(mapping)

# %%
df['Payment_Behaviour'].value_counts()

# %%
#Finding and setting a new column of an individual Income to its Total EMI ratio to get a proper visual idea
df['emi_to_income_ratio'] = (df['Total_EMI_per_month'] / df['Monthly_Inhand_Salary'] * 100).round(2)

# %%
#Dividing Age  to different Age groups to get a clear picture
bins = [10,18, 25, 35, 50, 100]
labels = ["10-17","18-25", "26-35", "36-50", "50+"]
df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=labels)

# %%
#Converting Credit_History_Years to years it is given in monthsa
df["Credit_History_Years"] = df["Credit_History_Age"] / 12
df["Credit_History_Years"]

# %%
#Finding the ratio of outstandinf debt to Annual income
df["Debt_to_Income"] = df["Outstanding_Debt"] / df["Annual_Income"]

# %%
#Mapping Month digits to Literal month names
month_map = {
    1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr",
    5: "May", 6: "Jun", 7: "Jul", 8: "Aug",
    9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"
}

df["Month"] = df["Month"].map(month_map)

# %%
#df['Annual_Income'] = np.log(df['Annual_Income'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?
#
# 1. **Removed Irrelevant Columns**:
# The columns 'ID', 'Customer_ID', 'SSN', and 'Name' were removed from the dataset.
# These columns only contain identification or personal information and do not help
# in analyzing or predicting credit scores.
#
# 2. **Simplified Payment Behaviour Labels**:
# The long values in the 'Payment_Behaviour' column were converted into shorter and
# easier labels (for example, 'Low_spent_Small_value_payments' was changed to 'Low_Small').
# This makes the values easier to read and use in analysis and visualizations.
#
# 3. **Created EMI to Income Ratio**:
# A new feature called 'emi_to_income_ratio' was created by dividing
# 'Total_EMI_per_month' by 'Monthly_Inhand_Salary' and converting it into percentage.
# This shows how much of a person’s monthly income is used to pay EMIs.
# Higher values may indicate higher financial burden.
#
# 4. **Grouped Age into Age Groups**:
# The 'Age' column was divided into age groups such as 10-17, 18-25, 26-35, 36-50, and 50+.
# This helps in analyzing financial behaviour across different age categories.
#
# 5. **Converted Credit History to Years**:
# The 'Credit_History_Age' column was originally in months, so it was converted
# into years by dividing by 12. This makes the credit history easier to understand.
#
# 6. **Created Debt to Income Ratio**:
# A new feature called 'Debt_to_Income' was created by dividing 'Outstanding_Debt'
# by 'Annual_Income'. This ratio helps to understand how much debt a person has
# compared to their income.
#
# 7. **Converted Month Numbers to Names**:
# The 'Month' column values were converted from numbers (1, 2, 3, etc.)
# to month names (Jan, Feb, Mar, etc.). This improves readability and makes
# it easier to analyze patterns across months.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
#Common method to show chart of different kinds

def plot_chart(df, chart_type, col1=None, col2=None, kde=False, figsize=(6,4)):

    plt.figure(figsize=figsize)

    # PIE CHART
    if chart_type == "pie":
        if col2:
            df.groupby(col1)[col2].sum().plot.pie(autopct='%1.1f%%')
            plt.title(f"{col2} by {col1}")
        else:
            df[col1].value_counts().plot.pie(autopct='%1.1f%%')
            plt.title(f"{col1} Distribution")
        plt.ylabel("")

    # BAR CHART
    elif chart_type == "bar":
        if col2:
            sns.barplot(data=df, x=col1, y=col2)
            plt.title(f"{col1} vs {col2}")
            plt.xticks(rotation=45)   # <-- slant labels
        else:
            sns.countplot(data=df, x=col1)
            plt.title(f"{col1} Count")

    # HISTOGRAM
    elif chart_type == "hist":
        if col2:
            sns.histplot(data=df, x=col1, hue=col2, kde=kde)
            plt.title(f"{col1} Distribution by {col2}")
            plt.xticks(rotation=45)
        else:
            sns.histplot(df[col1], kde=kde)
            plt.title(f"{col1} Distribution")

    # BOX PLOT
    elif chart_type == "box":
        if col2:
            sns.boxplot(data=df, x=col1, y=col2)
            plt.title(f"{col2} by {col1}")
            plt.xticks(rotation=45)
        else:
            sns.boxplot(x=df[col1])
            plt.title(f"{col1} Box Plot")

    # SCATTER PLOT
    elif chart_type == "scatter":
        if col2:
            sns.scatterplot(data=df, x=col1, y=col2)
            plt.title(f"{col1} vs {col2}")
        else:
            print("Scatter plot requires two columns")

    # HEATMAP
    elif chart_type == "heatmap":
        sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
        plt.title("Correlation Heatmap")

    else:
        print("Unsupported chart type")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Chart - 1 (Age)

# %%
# Chart - 1 (Age) visualization code
plot_chart(df, "bar", col1="Age_Group")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Bar charts** are useful for visualizing **categorical** or binned data.
# The height of each bar represents the count or frequency, making it easy to **compare different groups**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. **Data Entry Errors**
#
# The chart shows that around** 8–10%** of the data **contains improper entries, **
# where the age is **below 18.** Since people below 18 cannot legally take loans
# or use credit cards, these records may indicate data entry errors or
# incorrect data in the dataset.
#
# 2. **Data with Proper Entries**
#
# The age group between **18–25 **represents **around 20%** of the dataset,
# where individuals are either using credit cards, taking loans, or both.
#
# The age group between **26–35** represents around **30%** of the dataset,
# **showing a higher participation** in credit card usage or loans.
#
# The age group between **36–50** represents around **35%** of the dataset,
# which is the **highest among all** age groups. This indicates that
# **middle-aged** individuals are the **most active** in using credit cards
# or taking loans.
#
# The age group **51+** represents around **6%** of the dataset, which is the
# lowest among all groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes**, the insights gained from the analysis can help create a **positive business impact**.
#
# The age distribution shows that most customers who use credit cards or take loans fall between the age groups of** 26–35 and 36–50**. This means financial institutions can focus more on these age groups for marketing financial products such as credit cards, personal loans, or investment plans, which may **increase revenue and customer engagement**.
#
# The age group **18–25** also represents a **reasonable portion** of the dataset. Banks can target this group with **entry-level financial products**.
#
# However, there are also some insights that may **indicate negative growth or potential issues.** **Around 8–10%** of the data shows customers below 18 years of age. Since minors cannot legally take loans or own credit cards, this may indicate data entry errors or poor data quality. If such incorrect data is used for decision making, it may lead to incorrect business strategies.
#
# Therefore, improving data quality and focusing on the most active age groups can help businesses make better financial decisions and achieve positive growth.

# %% [markdown]
# #### Chart - 2(Annual Income)

# %%
# Chart - 2 visualization code
plot_chart(df, "hist", col1="Annual_Income", kde=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **histogram** was used because 'Annual_Income' is a **continuous variable**.
# This chart helps visualize the **distribution, spread, and density** of income values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# • The annual income data shows a wide spread, ranging from a few thousand
# to around 175,000, indicating large variation among customers.
#
# • The distribution appears to have multiple peaks, suggesting income
# clusters around ranges such as 20k–23k, 26k–40k, and around 60k–65k.
#
# • The distribution is highly right skewed, meaning most customers have
# lower to mid income while fewer customers have very high income.
#
# • Because of this skewness, applying a log transformation may help
# normalize the data for further analysis or modeling.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the annual income distribution can help create a positive business impact.
#
# The analysis shows that most customers fall into the low to middle income ranges, particularly between around 20k and 60k. This suggests that financial institutions can design financial products such as small to medium loans, flexible EMI plans, or entry-level credit cards targeted toward these income groups. By aligning products with the income capacity of the majority of customers, businesses can improve product adoption and customer satisfaction.
#
# However, there are also some insights that may indicate potential negative growth risks. The distribution is highly right skewed, meaning only a small portion of customers belong to the high income group. If financial institutions focus mainly on high-value financial products designed for high income individuals, a large portion of potential customers may be underserved. This could reduce market reach and limit business growth.
#
# Additionally, customers in lower income ranges may have higher financial risk, which could increase the chances of delayed payments or defaults if credit is not managed carefully. Therefore, proper credit risk assessment and tailored financial products are necessary to ensure sustainable growth.

# %% [markdown]
# #### Chart - 3(Interest Rate)

# %%
# Chart - 3 visualization code
plot_chart(df, "hist", col1="Interest_Rate", kde=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **histogram** was used because 'Intrest Rate' is a **continuous variable**.
# This chart helps visualize the **distribution, spread, and density** of Intrest Rates.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The interest rate distribution appears to be multimodal, with two noticeable peaks around the 5–10% and 15–20% ranges, indicating that many customers are taking loans within these interest brackets.
#
# *   The maximum interest rate observed in the dataset is around 35%.
#
# *   A significant number of customers are taking loans at interest rates above 20%, with some loans reaching up to 35%.
#
# *   The distribution shows that each interest rate range has more than 1,500 customers taking loans, indicating a strong demand for credit across different interest rate levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#     Yes, the insights from the interest rate distribution can help create a positive business impact.
#
# *    The analysis shows that a large number of customers are willing to take loans across a wide range of interest rates, including rates above 20%. This indicates strong demand for credit products in the market. Financial institutions can use this insight to design loan products for different customer segments, offering flexible interest rates based on customer risk profiles. This can help increase loan adoption and overall revenue.
#
# *    However, there are also some insights that may indicate potential negative growth risks. A significant number of customers are taking loans at very high interest rates, sometimes reaching up to 35%. High interest rates can increase the financial burden on customers and may lead to higher chances of delayed payments or loan defaults. If not managed properly, this could increase the bank’s credit risk and negatively affect long-term profitability.
#
#     Therefore, while the strong demand for loans presents a positive business opportunity, financial institutions must carefully assess customer creditworthiness and manage high interest rate loans to reduce potential risks.

# %% [markdown]
# #### Chart - 4 (EMI to Income Ratio)

# %%
# Chart - 4 visualization code
plot_chart(df, "box", col1="emi_to_income_ratio", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are useful for detecting outliers and understanding the spread of the data.
# Since the EMI to income ratio has many outliers and a wide range of values,
# a box plot is a good choice to analyze this data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Most customers have a low EMI to income ratio. This means only a small part of their monthly income is used to pay EMIs.
#
# *   The chart shows many outliers on the higher side, which means some customers are paying a very large portion of their income as EMI.
#
# *   The main data is concentrated at lower values, showing that most customers manage their loan payments comfortably.
#
# *   Some extreme values (above 100%) suggest that a few customers may be under financial stress or may have taken multiple loans.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#     The analysis shows that most customers have a manageable EMI compared to their income, which means banks may have opportunities to offer them additional financial products such as loans or credit cards. However, a small group of customers have very high EMI to income ratios, which may indicate financial stress and a higher risk of delayed payments or loan defaults. Therefore, while there is good opportunity for business growth, banks should carefully assess high-risk customers before approving new loans.

# %% [markdown]
# #### Chart - 5(Delay_from_due_date)

# %%
# Chart - 5 visualization code
plot_chart(df, "box", col1="Delay_from_due_date", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Using boxplot is very helpfull here, as i can see the data spread, also can see most of the people belong to high, low or meduim delay segment, find out the outliers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   The data is long spread as it goes few delays above 60 days
# *   The data has got few outliers as well, which in this case is good
# *   The data is right skewed although most of them are making under 30 days
# *   The half of the people are delayed in making payment is about 18 days

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  Most customers pay their bills late, usually within 30 days, with the typical delay being around 18 days. This means the company may often receive money later than expected, which can affect cash flow planning. A few customers delay payments for more than 60 days, which increases the risk of unpaid bills. The business can reduce this risk by monitoring customers with large delays and sending reminders or stricter payment rules.

# %% [markdown]
# #### Chart - 6(Number of Delayed Payment)

# %%
# Chart - 6 visualization code
plot_chart(df, "bar", col1="Num_of_Delayed_Payment", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are good when we need to comapre categorical data and also to see the pattern the given  data is following at a glance, here the number of delayed payment fits perfectly for analysys.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   People have made even highest 25 times the delayed payment
# *   We have around 2k people who have even payment on time, 0 delayed payment although overall percentage id quite small only 2% of overall data
# *   The trend clearly shows huge number people have made late payments ranging from 8 to 20 times as the bars are quite high in between

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The data shows that many customers make late payments frequently, with some customers paying late up to 25 times, while 8–20 late payments are quite common. This is concerning for banks and lenders because frequent late payments increase the risk of default. To reduce this risk, lenders should set a maximum limit for late payments and closely monitor customers who delay payments often.

# %% [markdown]
# #### Chart - 7(Changed Credit Limit)

# %%
# Chart - 7 visualization code
plot_chart(df, "hist", col1="Changed_Credit_Limit", figsize=(12,6))
# df['Changed_Credit_Limit'].value_counts().head(10).plot.pie(autopct='%1.1f%%')
# plt.ylabel("")
# plt.title(f"Changed_Credit_Limit Distribution")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this histogram (bar chart) because it helps show how the credit limit changes are distributed and how many customers fall into each range. It makes it easy to see which credit limit changes are most common.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Most customers have credit limit changes between 5 and 12.
#
# *  After 20, the number of customers drops a lot.
#
# *  Very few customers have very high credit limit changes (25–30).
#
# This means large credit limit changes are rare, and most adjustments are moderate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The bank mostly changes credit limits by small or moderate amounts rather than making very large changes. This helps the bank control lending risk and avoid giving too much credit suddenly. Customers with very high credit limit increases should be monitored carefully because they carry higher financial risk

# %% [markdown]
# #### Chart - 8 (Number of Credit Inquiries)

# %%
# Chart - 8 visualization code
plot_chart(df, "bar", col1="Num_Credit_Inquiries", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are quite good when you need to see the comparable pattern for all category, here number of credit enquiries are categorical values and height of the bars are indicator, number of people making the queries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The data is widely spread, which means people are making different numbers of credit card enquiries, and some people made up to 17 enquiries, showing a strong need for credit.
#
# *  The highest number of people (about 12k) made 4 enquiries, which is the most common behavior.
#
# *  The number of people making enquiries gradually increases from 0 to 3 enquiries.
#
# *  It is interesting that many people did not make even a single enquiry.
#
# A large number of people also made 6–8 enquiries, showing that some customers repeatedly search for credit cards.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This shows that many people are actively looking for credit cards, and some apply multiple times. Banks can target these high-interest customers, but they should also check risk carefully for people making too many enquiries, as it may indicate financial stress

# %% [markdown]
# #### Chart - 9(Outstanding Debt)

# %%
# Chart - 9 visualization code
plot_chart(df, "hist", col1="Outstanding_Debt", kde=True, figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Outstanding debt is a continuous variable, so it is best shown using a chart that displays how values are spread across different ranges. This helps us see where most customers’ debt is concentrated and identify peaks in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Most customers have low to medium debt (0–1500).
#
# *  There is another group with higher debt (around 2200–2800).
#
# *  A small number of customers have very high debt (3000–5000).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Low debt customers**: Low risk, normal monitoring.
#
# **Medium debt customers**: Send payment reminders to prevent debt from increasing.
#
# **High debt customers**: Higher risk but revenue generating ; may need stricter credit limits or repayment plans to keep from defaults.

# %% [markdown]
# #### Chart - 10(Payment Behaviour)

# %%
# Chart - 10 visualization code
plot_chart(df, "bar", col1="Payment_Behaviour",  figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Payment behaviour is categorical data, so a bar chart is better to show the pattern clearly. A bar chart makes it easy to compare the different categories of payment behaviour.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  Low_Small has the highest number of customers. This means many customers make small payments regularly.
#
# *  High_Medium and High_Large also have a good number of customers, meaning some customers pay larger amounts.
#
# *  Low_Large has the lowest count, so fewer customers make large payments infrequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *  Customers with Low_Small payments may take longer to clear their debt, so monitoring is important.
#
# *  Customers making High_Medium or High_Large payments are better at reducing their debt.
#
# *  The company can encourage larger payments (discounts or rewards) to help reduce outstanding balances faster.

# %% [markdown]
# #### Chart - 11(Annual income vs occupation )

# %%
# Chart - 11 visualization code
plot_chart(df, "box", col1="Occupation", col2="Annual_Income", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are very useful for comparing a continuous variable across different categories. In this case, they help us understand the distribution of values for each category. The whiskers show the spread of the data, while the box represents the interquartile range. By comparing the median, minimum, and maximum values across categories, we can easily identify differences, variability, and possible outliers in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The box plot indicates that almost every occupation has a very similar data spread and variability in income. In reality, this is unlikely because different occupations usually have significantly different income distributions. This may indicate possible issues with the dataset, such as improper data collection, incorrect labeling, or data quality problems.
#
# *  The income range appears to start from a few thousand and goes up to around ₹1.75 lakhs across nearly all occupations, which again suggests an unusually uniform distribution of income across categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Poor data quality in income information can lead to incorrect business insights and unreliable credit risk decisions, potentially increasing financial losses or rejecting eligible customers. Ensuring proper data collection and validation is critical for accurate analysis.

# %% [markdown]
# #### Chart - 12(Age vs Number of loan)

# %%
# Chart - 12 visualization code
plot_chart(df, "bar", col1="Age_Group", col2="Num_of_Loan", figsize=(12,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are effective for comparing values across categories. Here, age groups are the categories and the number of loans is discrete data, making a bar chart a suitable way to visualize and compare loan patterns across different age groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The 10–17 age group shows the highest number of loans, which is unrealistic because individuals in this age group are typically not eligible for loans. This strongly indicates **poor data quality or incorrect data entry.**
#
# *  The 18–25 and 26–35 age groups have a similar average number of loans, around 3.75, suggesting that younger adults tend to take multiple loans, possibly due to early career needs, education, or lifestyle expenses.
#
# *  The 36–50 age group shows fewer loans compared to the younger age groups, which may indicate that individuals in this stage of life are more financially stable or have already paid off earlier loans.
#
# *  The 50+ age group has the lowest number of loans, which aligns with real-world expectations, as people in this age group often have established finances and lower borrowing needs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If such data is used for credit risk modeling or loan approval systems, it may distort age-based risk patterns and reduce model accuracy.
#
# Financial institutions relying on this analysis may misidentify target customer segments, leading to poor lending strategies or increased credit risk.
#
# Therefore, data validation rules (such as minimum eligible age for loans) should be implemented during data collection and preprocessing

# %% [markdown]
# #### Chart - 13 (Payment of Min Amount vs Monthly in-hand salary)

# %%
# Chart - 13 visualization code
plot_chart(df, "box", col1="Payment_of_Min_Amount", col2="Monthly_Inhand_Salary", figsize=(8,6))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are very useful for comparing the spread of data and the interquartile range across different categories. In this case, they help analyze the distribution of monthly in-hand salary across the Yes, No, and NM categories, making it easier to observe differences in median values, variability, and potential outliers among these groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *  The “No” category shows the largest interquartile range (IQR) in terms of monthly in-hand salary, indicating higher variability in income within this group. The median salary appears to be around ₹4k, meaning about 50% of the individuals earn below this level, while the upper range extends to around ₹16k. However, this salary distribution seems unusually low and may indicate data quality or scaling issues.
#
# *  The “NM” category shows a moderate interquartile range, with the median monthly in-hand salary around ₹6k. There are also several outliers extending up to around ₹16k, suggesting that a few individuals in this group earn significantly higher salaries than the majority.
#
# *  The “Yes” category has the lowest monthly in-hand salary distribution, which aligns with expectations if this category represents individuals facing financial constraints. Some outliers reach up to around ₹12k, but these individuals may still struggle to meet their obligations due to other financial commitments or expenses.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The unusually low salary values and similar upper ranges across categories may indicate poor data quality, incorrect scaling, or data entry issues, which could lead to misleading financial insights.
#
# If such data is used for credit scoring or repayment prediction models, it could result in incorrect assessment of customers’ repayment capacity, increasing the risk of loan defaults or poor lending decisions.
#
# Therefore, data validation and normalization of salary information should be performed before building any analytical models or making business decisions

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
